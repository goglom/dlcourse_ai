# %% [markdown]
# # Задание 3.1 - Сверточные нейронные сети (Convolutional Neural Networks)
#
# Это последнее задание на numpy, вы до него дожили! Остался последний марш-бросок, дальше только PyTorch.
#
# В этом задании вы реализуете свою собственную сверточную нейронную сеть.

# %%
from google.colab import drive
import os
drive.mount('/content/drive', force_remount=True)
assignment_dir = "/content/drive/MyDrive/dlcourse_ai-master/assignments/assignment3"
os.chdir(assignment_dir)
assert os.getcwd() == assignment_dir
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %reload_ext autoreload

# %autoreload 2

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_layer_gradient, check_layer_param_gradient, check_model_gradient
from layers import FullyConnectedLayer, ReLULayer, ConvolutionalLayer, MaxPoolingLayer, Flattener
from model import ConvNet
from trainer import Trainer, Dataset
from optim import SGD, MomentumSGD
from metrics import multiclass_accuracy

# %% [markdown]
# # Загружаем данные
#
# На этот раз мы не будем их преобразовывать в один вектор, а оставим размерности (num_samples, 32, 32, 3).

# %%
def prepare_for_neural_network(train_X, test_X):    
    train_X = train_X.astype(np.float) / 255.0
    test_X = test_X.astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_X, axis = 0)
    train_X -= mean_image
    test_X -= mean_image
    
    return train_X, test_X
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_neural_network(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Реализуем новые слои!
#
# Сначала основной новый слой - сверточный (Convolutional layer).
# Для начала мы реализуем его для только одного канала, а потом для нескольких.
#
# Сверточный слой выполняет операцию свертки (convolution) с весами для каждого канала, а потом складывает результаты.
# Возможно, поможет пересмотреть Лекцию 6 или внимательно прочитать
# http://cs231n.github.io/convolutional-networks/
#
# Один из подходов к реализации сверточного слоя основан на том, что для конкретного "пикселя" выхода применение сверточного слоя эквивалентно обычному полносвязному.
# Рассмотрим один такой "пиксель":
# ![image.png](attachment:image.png)
#
# Он получает на вход
# регион входа I размера `(batch_size, filter_size, filter_size, input_channels)`,
# применяет к нему веса W `(filter_size, filter_size, input_channels, output_channels`
# и выдает `(batch_size, output_channels)`.
#
# Если:
# - вход преобразовать в I' `(batch_size, filter_size*filter_size*input_channels)`,
# - веса в W' `(filter_size*filter_size*input_channels, output_channels)`,
# то выход "пикселе" будет эквивалентен полносвязному слою со входом I' и весами W'.
#
# Осталось выполнить его в цикле для каждого пикселя :)

# %%
# TODO: Implement ConvolutionaLayer that supports only 1 output and input channel

# Note: now you're working with images, so X is 4-dimensional tensor of
# (batch_size, height, width, channels)

X = np.array([
              [
               [[1.0], [2.0]],
               [[0.0], [-1.0]]
              ]
              ,
              [
               [[0.0], [1.0]],
               [[-2.0], [-1.0]]
              ]
             ])

# Batch of 2 images of dimensions 2x2 with a single channel
print("Shape of X:",X.shape)

layer = ConvolutionalLayer(in_channels=1, out_channels=1, filter_size=2, padding=0)
print("Shape of W", layer.W.value.shape)
layer.W.value = np.zeros_like(layer.W.value)
layer.W.value[0, 0, 0, 0] = 1.0
layer.B.value = np.ones_like(layer.B.value)
result = layer.forward(X)

assert result.shape == (2, 1, 1, 1)
assert np.all(result == X[:, :1, :1, :1] +1), "result: %s, X: %s" % (result, X[:, :1, :1, :1])


# Now let's implement multiple output channels
layer = ConvolutionalLayer(in_channels=1, out_channels=2, filter_size=2, padding=0)
result = layer.forward(X)
assert result.shape == (2, 1, 1, 2)


# And now multple input channels!
X = np.array([
              [
               [[1.0, 0.0], [2.0, 1.0]],
               [[0.0, -1.0], [-1.0, -2.0]]
              ]
              ,
              [
               [[0.0, 1.0], [1.0, -1.0]],
               [[-2.0, 2.0], [-1.0, 0.0]]
              ]
             ])

print("Shape of X:", X.shape)
layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=2, padding=0)
result = layer.forward(X)
assert result.shape == (2, 1, 1, 2)
# Out:
# Shape of X: (2, 2, 2, 1)
# Shape of W (2, 2, 1, 1)
# Shape of X: (2, 2, 2, 2)

# %% [markdown]
# ## А теперь имплементируем обратный проход
# Возможно, это самое сложное место в курсе. Дальше будет лучше.
#
# Раз выполнение сверточного слоя эквивалентно полносвязному слою для каждого "пикселя" выхода, то общий обратный проход эквивалентен обратному проходу каждого из таких "слоев".
# Градиенты от каждого из этих "слоев" в каждом пикселе надо сложить в соответствующие пиксели градиента по входу, а градиенты весов сложить все вместе.

# %%
# First test - check the shape is right
layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=2, padding=0)
result = layer.forward(X)
d_input = layer.backward(np.ones_like(result))

assert d_input.shape == X.shape, (d_input.shape, X.shape)

# Actually test the backward pass
# As usual, you'll need to copy gradient check code from the previous assignment
layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=2, padding=0)
assert check_layer_gradient(layer, X)

layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=2, padding=0)
assert check_layer_param_gradient(layer, X, 'W')
layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=2, padding=0)
assert check_layer_param_gradient(layer, X, 'B')
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# Осталось реализовать дополнение нулями (padding).
# Достаточно дополнить входной тензор нулями по сторонам. Не забудьте учесть это при обратном проходе!

# %%
layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=3, padding=1)
result = layer.forward(X)
# Note this kind of layer produces the same dimensions as input
assert result.shape == X.shape,"Result shape: %s - Expected shape %s" % (result.shape, X.shape)
d_input = layer.backward(np.ones_like(result))
assert d_input.shape == X.shape, (d_input.shape, X.shape)
layer = ConvolutionalLayer(in_channels=2, out_channels=2, filter_size=3, padding=1)
assert check_layer_gradient(layer, X)
# Out:
# Gradient check passed!

# %% [markdown]
# ## После следующего слоя вам уже будет все ни по чем - max pooling
#
# Max Pooling - это слой, реализующий операцию максимума для каждого канала отдельно в окресности из `pool_size` "пикселей".
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/e/e9/Max_pooling.png)
#
# И напомним что такое stride.
# Stride - это на сколько "пикселей" сдвигается окно на одном шаге.
# Вот здесь, например, stride = 2
#
# ![image.png](http://deeplearning.net/software/theano/_images/no_padding_strides.gif)
#
# На практике, для max pooling значение stride часто равно pool size.

# %%
pool = MaxPoolingLayer(2, 2)
result = pool.forward(X)

assert result.shape == (2, 1, 1, 2)
assert check_layer_gradient(pool, X)
# Out:
# Gradient check passed!

# %% [markdown]
# И на закуску - слой, преобразующий четырехмерные тензоры в двумерные.
#
# Этот слой понадобится нам, чтобы в конце сети перейти от сверточных слоев к полносвязным.

# %%
flattener = Flattener()
result = flattener.forward(X)
assert result.shape == (2,8)

assert check_layer_gradient(flattener, X)
# Out:
# Gradient check passed!

# %% [markdown]
# # Теперь есть все кирпичики, создаем модель

# %%
# TODO: In model.py, implement missed functions function for ConvNet model

# No need to use L2 regularization
model = ConvNet(input_shape=(32,32,3), n_output_classes=10, conv1_channels=2, conv2_channels=2)
loss = model.compute_loss_and_gradients(train_X[:2], train_y[:2])

# TODO Now implement backward pass and aggregate all of the params
check_model_gradient(model, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W1
# Gradient check passed!
# Checking gradient for B1
# Gradient check passed!
# Checking gradient for W2
# Gradient check passed!
# Checking gradient for B2
# Gradient check passed!
# Checking gradient for W3
# Gradient check passed!
# Checking gradient for B3
# Gradient check passed!
# True

# %% [markdown]
# # Оптимизатор и код для тренировки
# Должен заработать с кодом из прошлого задания без изменений!

# %%
model = ConvNet(input_shape=(32,32,3), n_output_classes=10, conv1_channels=2, conv2_channels=2)
N = 32
dataset = Dataset(train_X[:N], train_y[:N], val_X[:N], val_y[:N])
trainer = Trainer(model, dataset, SGD(), batch_size=16, learning_rate=1e-1)

loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 2.367146, Train accuracy: 0.281250, val accuracy: 0.093750
# Loss: 2.125089, Train accuracy: 0.281250, val accuracy: 0.125000
# Loss: 2.126878, Train accuracy: 0.312500, val accuracy: 0.093750
# Loss: 2.127554, Train accuracy: 0.312500, val accuracy: 0.062500
# Loss: 2.313263, Train accuracy: 0.281250, val accuracy: 0.062500
# Loss: 1.884381, Train accuracy: 0.281250, val accuracy: 0.062500
# Loss: 2.019475, Train accuracy: 0.312500, val accuracy: 0.093750
# Loss: 1.777398, Train accuracy: 0.343750, val accuracy: 0.093750
# Loss: 1.926221, Train accuracy: 0.406250, val accuracy: 0.125000
# Loss: 1.686941, Train accuracy: 0.312500, val accuracy: 0.093750
# Loss: 1.946791, Train accuracy: 0.312500, val accuracy: 0.062500
# Loss: 2.230076, Train accuracy: 0.437500, val accuracy: 0.156250
# Loss: 1.830525, Train accuracy: 0.406250, val accuracy: 0.156250
# Loss: 1.976691, Train accuracy: 0.437500, val accuracy: 0.156250
# Loss: 1.852377, Train accuracy: 0.468750, val accuracy: 0.156250
# Loss: 1.888881, Train accuracy: 0.468750, val accuracy: 0.187500
# Loss: 1.838644, Train accuracy: 0.500000, val accuracy: 0.156250
# Loss: 1.584852, Train accuracy: 0.468750, val accuracy: 0.156250
# Loss: 1.861426, Train accuracy: 0.531250, val accuracy: 0.156250
# Loss: 1.874812, Train accuracy: 0.500000, val accuracy: 0.187500

# %%
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# # Последнее упражнение
# В качестве последнего упражнения мы доведем точность на тренировочном наборе данных до 100% на небольшом наборе данных.
# Сверточные сети требуют большого количества вычислений и аккуратной эффективной реализации, поэтому настоящие модели мы будем тренировать уже на PyTorch в следующем задании.

# %% [markdown]
# ## Итак, оверфитим маленький набор данных

# %%
data_size = 128
model = ConvNet(input_shape=(32,32,3), n_output_classes=10, conv1_channels=16, conv2_channels=32)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
# TODO: Change any hyperparamers or optimizators to reach 1.0 training accuracy in 50 epochs or less
# Hint: If you have hard time finding the right parameters manually, try grid search or random search!
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-3, num_epochs=50, batch_size=4)

loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 9.740874, Train accuracy: 0.156250, val accuracy: 0.171875
# Loss: 2.432486, Train accuracy: 0.210938, val accuracy: 0.125000
# Loss: 3.322208, Train accuracy: 0.453125, val accuracy: 0.140625
# Loss: 2.319332, Train accuracy: 0.359375, val accuracy: 0.117188
# Loss: 1.266169, Train accuracy: 0.328125, val accuracy: 0.226562
# Loss: 1.833153, Train accuracy: 0.453125, val accuracy: 0.148438
# Loss: 3.431348, Train accuracy: 0.585938, val accuracy: 0.164062
# Loss: 2.082744, Train accuracy: 0.632812, val accuracy: 0.148438
# Loss: 1.740648, Train accuracy: 0.601562, val accuracy: 0.085938
# Loss: 0.696803, Train accuracy: 0.500000, val accuracy: 0.101562
# Loss: 0.673458, Train accuracy: 0.679688, val accuracy: 0.164062
# Loss: 0.992809, Train accuracy: 0.687500, val accuracy: 0.195312
# Loss: 1.454119, Train accuracy: 0.640625, val accuracy: 0.101562
# Loss: 0.790183, Train accuracy: 0.742188, val accuracy: 0.132812
# Loss: 0.784372, Train accuracy: 0.773438, val accuracy: 0.125000
# Loss: 0.371887, Train accuracy: 0.773438, val accuracy: 0.125000
# Loss: 0.944506, Train accuracy: 0.703125, val accuracy: 0.132812
# Loss: 3.661961, Train accuracy: 0.554688, val accuracy: 0.148438
# Loss: 0.204086, Train accuracy: 0.726562, val accuracy: 0.156250
# Loss: 0.374144, Train accuracy: 0.843750, val accuracy: 0.109375
# Loss: 1.221225, Train accuracy: 0.851562, val accuracy: 0.093750
# Loss: 0.866557, Train accuracy: 0.867188, val accuracy: 0.148438
# Loss: 0.422468, Train accuracy: 0.914062, val accuracy: 0.132812
# Loss: 0.598626, Train accuracy: 0.914062, val accuracy: 0.132812
# Loss: 0.909081, Train accuracy: 0.890625, val accuracy: 0.109375
# Loss: 0.218881, Train accuracy: 0.890625, val accuracy: 0.125000
# Loss: 0.503589, Train accuracy: 0.921875, val accuracy: 0.148438
# Loss: 0.247806, Train accuracy: 0.953125, val accuracy: 0.140625
# Loss: 0.774667, Train accuracy: 0.976562, val accuracy: 0.148438
# Loss: 0.644033, Train accuracy: 0.976562, val accuracy: 0.171875
# Loss: 0.060929, Train accuracy: 0.984375, val accuracy: 0.132812
# Loss: 0.374360, Train accuracy: 0.984375, val accuracy: 0.132812
# Loss: 0.244044, Train accuracy: 0.992188, val accuracy: 0.195312
# Loss: 0.133284, Train accuracy: 0.992188, val accuracy: 0.125000
# Loss: 0.258470, Train accuracy: 1.000000, val accuracy: 0.164062
# Loss: 0.560562, Train accuracy: 0.960938, val accuracy: 0.125000
# Loss: 0.201477, Train accuracy: 0.976562, val accuracy: 0.179688
# Loss: 0.303974, Train accuracy: 0.984375, val accuracy: 0.156250
# Loss: 0.093728, Train accuracy: 1.000000, val accuracy: 0.148438
# Loss: 0.487722, Train accuracy: 0.984375, val accuracy: 0.125000
# Loss: 0.294312, Train accuracy: 1.000000, val accuracy: 0.085938
# Loss: 0.047717, Train accuracy: 0.992188, val accuracy: 0.101562
# Loss: 0.225041, Train accuracy: 1.000000, val accuracy: 0.117188
# Loss: 0.352253, Train accuracy: 0.976562, val accuracy: 0.093750
# Loss: 0.040533, Train accuracy: 1.000000, val accuracy: 0.125000
# Loss: 0.265340, Train accuracy: 1.000000, val accuracy: 0.132812
# Loss: 0.303499, Train accuracy: 1.000000, val accuracy: 0.140625
# Loss: 0.204485, Train accuracy: 1.000000, val accuracy: 0.117188
# Loss: 0.098397, Train accuracy: 1.000000, val accuracy: 0.125000
# Loss: 0.142557, Train accuracy: 1.000000, val accuracy: 0.109375

# %%
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# Дальнейшие упражнения - уже на PyTorch, открывайте следующий notebook!
#
# ![image.png](attachment:image.png)
